# %%
import networkx as nx
from graphs import StarGraph
from graphs.utils import subdivide
from graphs.tools import draw_graphs
from graphs.graceful_labellings import find_pm_valuations

edges = subdivide(StarGraph.edges(3))

graph = nx.Graph(edges)

draw_graphs(find_pm_valuations(graph))
# Out:
#     <div id="slideshow_aab4a6a47451422c9564f7cdb2e994bb-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_aab4a6a47451422c9564f7cdb2e994bb-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_aab4a6a47451422c9564f7cdb2e994bb-counter">1 / 24</span>
#         </div>
#         <button id="slideshow_aab4a6a47451422c9564f7cdb2e994bb-prev">Previous</button>
#         <button id="slideshow_aab4a6a47451422c9564f7cdb2e994bb-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
# ...

# %%
from graphs import CycleGraph, PathGraph
from graphs.graceful_labellings import find_alpha_valuations

edge_sets = [
    PathGraph.edges(4),
    PathGraph.edges(5),
    PathGraph.edges(6),
    CycleGraph.edges(4),
    CycleGraph.edges(8),
]

for edges in edge_sets:
    graph = nx.Graph(edges)

    draw_graphs(find_alpha_valuations(graph))
    draw_graphs(find_pm_valuations(graph))
# Out:
#     <div id="slideshow_96286ffa80cd4ce5be0e96d6b1175df9-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_96286ffa80cd4ce5be0e96d6b1175df9-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_96286ffa80cd4ce5be0e96d6b1175df9-counter">1 / 4</span>
#         </div>
#         <button id="slideshow_96286ffa80cd4ce5be0e96d6b1175df9-prev">Previous</button>
#         <button id="slideshow_96286ffa80cd4ce5be0e96d6b1175df9-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_96286ffa80cd4ce5be0e96d6b1175df9-img").src = "data:image/png;base64," + images[i];
# ...

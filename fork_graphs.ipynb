# %%
from graphs import ForkGraph
from graphs.utils import Edge, Vertex

graceful_forks: list[tuple[list[Vertex], list[Edge]]] = [
    ([1, 0, 2, 5, 3, 4, 6], [(1, 0), (0, 2), (2, 5), (5, 3), (3, 4), (6, 3)]),
]

for vertices, edges in graceful_forks:
    ForkGraph(vertices, edges).draw()

# %%
from graphs import ForkGraph
from graphs.graceful_labellings.alpha_valuations import fork_1

for n_vertices in range(3, 9):
    ForkGraph.from_vertices(fork_1(n_vertices)).draw()

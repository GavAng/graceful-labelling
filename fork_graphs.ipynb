# %%
from graph_types import ForkGraph

graceful_forks = [
    {"path": ((1, 0), (0, 2)), "ends": ((2, 3), (2, 5))},
    {"path": ((1, 0), (0, 2), (2, 5), (5, 3)), "ends": ((3, 4), (6, 3))},
]

for graceful_fork in graceful_forks:
    ForkGraph(**graceful_fork).draw()
# Out:
# {1: (0, 0), 0: (1, 0), 2: (2, 0), 3: (2.7071067811865475, 0.35355339059327373), 5: (2.7071067811865475, -0.35355339059327373)}
# {1: (0, 0), 0: (1, 0), 2: (2, 0), 3: (2.7071067811865475, 0.35355339059327373), 5: (2.7071067811865475, -0.35355339059327373)}
# {1: (0, 0), 0: (1, 0), 2: (2, 0), 5: (3, 0), 3: (4, 0), 4: (4.707106781186548, 0.35355339059327373), 6: (4.707106781186548, -0.35355339059327373)}
# {1: (0, 0), 0: (1, 0), 2: (2, 0), 5: (3, 0), 3: (4, 0), 4: (4.707106781186548, 0.35355339059327373), 6: (4.707106781186548, -0.35355339059327373)}

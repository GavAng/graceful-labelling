# %%
from graphs import ForkGraph

graceful_forks = [
    {
        "path": ((1, 0), (0, 2)),
        "ends": ((2, 3), (2, 5)),
    },
    {
        "path": ((1, 0), (0, 2), (2, 5), (5, 3)),
        "ends": ((3, 4), (6, 3)),
    },
]

for graceful_fork in graceful_forks:
    ForkGraph(**graceful_fork).draw()
# Out:
# ((1, 0), (0, 2))
# ((1, 0), (0, 2), (2, 5), (5, 3))

# %%
from graphs import ForkGraph
from graceful_labellings.alpha_valuations import fork_1

ForkGraph(**fork_1(5)).draw()
ForkGraph(**fork_1(6)).draw()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       1 from graphs import ForkGraph
#       2 from graceful_labellings.alpha_valuations import fork_1
# ----> 4 ForkGraph(**fork_1(5)).draw()
#       5 ForkGraph(**fork_1(6)).draw()
#
# File c:\Users\Gavin Angus\Documents\_main\code\git\graceful-labelling\graphs\fork_graph.py:19, in ForkGraph.__init__(self, path, ends)
#      18 def __init__(self, path: PathGraph, ends: tuple[Edge, Edge]):
# ---> 19     super().from_edges(chain(path.edges, ends))
#      20     ends_common = set(ends[0]) & set(ends[1])
#      21     connector = next(iter(ends_common))
#
# File c:\Users\Gavin Angus\Documents\_main\code\git\graceful-labelling\graphs\directed_graph.py:27, in DirectedGraph.from_edges(cls, edges)
#      24 @classmethod
#      25 def from_edges(cls, edges: Iterable[Edge]):
# ...

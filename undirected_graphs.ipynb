# %%
import networkx as nx

from graphs import PathGraph, CycleGraph, CompleteGraph, StarGraph, SunGraph, WheelGraph
from graphs.tools import draw_graphs
from graphs.graceful_labellings import (
    find_graceful_labellings,
    find_alpha_valuations,
    find_eta_valuations,
)
from graphs.utils import Position, Vertex

# %%
for n_vertices in range(2, 8):
    P_n = nx.Graph(PathGraph.edges(n_vertices))
    draw_graphs(find_alpha_valuations(P_n), layout=PathGraph.layout(n_vertices))
# Out:
#     <div id="slideshow_ad937919d2a542ec8c23d6fdcb66c150-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_ad937919d2a542ec8c23d6fdcb66c150-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_ad937919d2a542ec8c23d6fdcb66c150-counter">1 / 2</span>
#         </div>
#         <button id="slideshow_ad937919d2a542ec8c23d6fdcb66c150-prev">Previous</button>
#         <button id="slideshow_ad937919d2a542ec8c23d6fdcb66c150-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_ad937919d2a542ec8c23d6fdcb66c150-img").src = "data:image/png;base64," + images[i];
#                 document.getElementById("slideshow_ad937919d2a542ec8c23d6fdcb66c150-counter").textContent = (i + 1) + " / " + total;
#             }
#
#             document.getElementById("slideshow_ad937919d2a542ec8c23d6fdcb66c150-prev").onclick = function() {
#                 index = (index - 1 + images.length) % images.length;
#                 showImage(index);
#             };
#             document.getElementById("slideshow_ad937919d2a542ec8c23d6fdcb66c150-next").onclick = function() {
#                 index = (index + 1) % images.length;
#                 showImage(index);
#             };
#         })();
#     </script>
#     <div id="slideshow_9380cee232724826ae63dffc83400885-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_9380cee232724826ae63dffc83400885-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_9380cee232724826ae63dffc83400885-counter">1 / 4</span>
#         </div>
#         <button id="slideshow_9380cee232724826ae63dffc83400885-prev">Previous</button>
#         <button id="slideshow_9380cee232724826ae63dffc83400885-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_9380cee232724826ae63dffc83400885-img").src = "data:image/png;base64," + images[i];
#                 document.getElementById("slideshow_9380cee232724826ae63dffc83400885-counter").textContent = (i + 1) + " / " + total;
#             }
#
#             document.getElementById("slideshow_9380cee232724826ae63dffc83400885-prev").onclick = function() {
#                 index = (index - 1 + images.length) % images.length;
#                 showImage(index);
#             };
#             document.getElementById("slideshow_9380cee232724826ae63dffc83400885-next").onclick = function() {
#                 index = (index + 1) % images.length;
#                 showImage(index);
#             };
#         })();
#     </script>
#     <div id="slideshow_42088d056df94814ab7d1b121f16d80d-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_42088d056df94814ab7d1b121f16d80d-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_42088d056df94814ab7d1b121f16d80d-counter">1 / 4</span>
#         </div>
#         <button id="slideshow_42088d056df94814ab7d1b121f16d80d-prev">Previous</button>
#         <button id="slideshow_42088d056df94814ab7d1b121f16d80d-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_42088d056df94814ab7d1b121f16d80d-img").src = "data:image/png;base64," + images[i];
#                 document.getElementById("slideshow_42088d056df94814ab7d1b121f16d80d-counter").textContent = (i + 1) + " / " + total;
#             }
#
#             document.getElementById("slideshow_42088d056df94814ab7d1b121f16d80d-prev").onclick = function() {
#                 index = (index - 1 + images.length) % images.length;
#                 showImage(index);
#             };
#             document.getElementById("slideshow_42088d056df94814ab7d1b121f16d80d-next").onclick = function() {
#                 index = (index + 1) % images.length;
#                 showImage(index);
#             };
#         })();
#     </script>
#     <div id="slideshow_b38ad6f33c52462a85f62f2d48c68778-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_b38ad6f33c52462a85f62f2d48c68778-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_b38ad6f33c52462a85f62f2d48c68778-counter">1 / 4</span>
#         </div>
#         <button id="slideshow_b38ad6f33c52462a85f62f2d48c68778-prev">Previous</button>
#         <button id="slideshow_b38ad6f33c52462a85f62f2d48c68778-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_b38ad6f33c52462a85f62f2d48c68778-img").src = "data:image/png;base64," + images[i];
#                 document.getElementById("slideshow_b38ad6f33c52462a85f62f2d48c68778-counter").textContent = (i + 1) + " / " + total;
#             }
#
#             document.getElementById("slideshow_b38ad6f33c52462a85f62f2d48c68778-prev").onclick = function() {
#                 index = (index - 1 + images.length) % images.length;
#                 showImage(index);
#             };
#             document.getElementById("slideshow_b38ad6f33c52462a85f62f2d48c68778-next").onclick = function() {
#                 index = (index + 1) % images.length;
#                 showImage(index);
#             };
#         })();
#     </script>
#     <div id="slideshow_0feafe1d1afe45848ee11a93da709861-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_0feafe1d1afe45848ee11a93da709861-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_0feafe1d1afe45848ee11a93da709861-counter">1 / 8</span>
#         </div>
#         <button id="slideshow_0feafe1d1afe45848ee11a93da709861-prev">Previous</button>
#         <button id="slideshow_0feafe1d1afe45848ee11a93da709861-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","...","...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_0feafe1d1afe45848ee11a93da709861-img").src = "data:image/png;base64," + images[i];
#                 document.getElementById("slideshow_0feafe1d1afe45848ee11a93da709861-counter").textContent = (i + 1) + " / " + total;
#             }
#
#             document.getElementById("slideshow_0feafe1d1afe45848ee11a93da709861-prev").onclick = function() {
#                 index = (index - 1 + images.length) % images.length;
#                 showImage(index);
#             };
#             document.getElementById("slideshow_0feafe1d1afe45848ee11a93da709861-next").onclick = function() {
#                 index = (index + 1) % images.length;
#                 showImage(index);
#             };
#         })();
#     </script>
#     <div id="slideshow_c219931d97a64f6daad9640b4f0f1654-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_c219931d97a64f6daad9640b4f0f1654-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_c219931d97a64f6daad9640b4f0f1654-counter">1 / 16</span>
#         </div>
#         <button id="slideshow_c219931d97a64f6daad9640b4f0f1654-prev">Previous</button>
#         <button id="slideshow_c219931d97a64f6daad9640b4f0f1654-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_c219931d97a64f6daad9640b4f0f1654-img").src = "data:image/png;base64," + images[i];
#                 document.getElementById("slideshow_c219931d97a64f6daad9640b4f0f1654-counter").textContent = (i + 1) + " / " + total;
#             }
#
#             document.getElementById("slideshow_c219931d97a64f6daad9640b4f0f1654-prev").onclick = function() {
#                 index = (index - 1 + images.length) % images.length;
#                 showImage(index);
#             };
#             document.getElementById("slideshow_c219931d97a64f6daad9640b4f0f1654-next").onclick = function() {
#                 index = (index + 1) % images.length;
#                 showImage(index);
#             };
#         })();
#     </script>

# %%
rosa_star = [(1, 2), (2, 0), (3, 4), (4, 0), (5, 6), (6, 0)]

edge_sets = [
    CycleGraph.edges(4),
    rosa_star,
    PathGraph.edges(5),
]
layouts: list[dict[Vertex, Position] | None] = [
    CycleGraph.layout(4),
    None,
    PathGraph.layout(5),
]

for edges, layout in zip(edge_sets, layouts):
    print(f"Graph {edges}")
    graph = nx.Graph(edges)
    print("Graceful labellings:")
    try:
        draw_graphs(find_graceful_labellings(graph), layout=layout)
    except StopIteration:
        print("No graceful labellings found.")
    print("Alpha-valuations:")
    try:
        draw_graphs(find_alpha_valuations(graph), layout=layout)
    except StopIteration:
        print("No alpha-valuations found.")
# Out:
# Graph [(0, 1), (1, 2), (2, 3), (3, 0)]
# Graceful labellings:
#     <div id="slideshow_00ac6caea61c46ccb49af588d2587908-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_00ac6caea61c46ccb49af588d2587908-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_00ac6caea61c46ccb49af588d2587908-counter">1 / 16</span>
#         </div>
#         <button id="slideshow_00ac6caea61c46ccb49af588d2587908-prev">Previous</button>
#         <button id="slideshow_00ac6caea61c46ccb49af588d2587908-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_00ac6caea61c46ccb49af588d2587908-img").src = "data:image/png;base64," + images[i];
#                 document.getElementById("slideshow_00ac6caea61c46ccb49af588d2587908-counter").textContent = (i + 1) + " / " + total;
#             }
#
#             document.getElementById("slideshow_00ac6caea61c46ccb49af588d2587908-prev").onclick = function() {
#                 index = (index - 1 + images.length) % images.length;
#                 showImage(index);
#             };
#             document.getElementById("slideshow_00ac6caea61c46ccb49af588d2587908-next").onclick = function() {
#                 index = (index + 1) % images.length;
#                 showImage(index);
#             };
#         })();
#     </script>
# Alpha-valuations:
#     <div id="slideshow_b8e38ba392d44ca085c10f7085e57a50-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_b8e38ba392d44ca085c10f7085e57a50-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_b8e38ba392d44ca085c10f7085e57a50-counter">1 / 16</span>
#         </div>
#         <button id="slideshow_b8e38ba392d44ca085c10f7085e57a50-prev">Previous</button>
#         <button id="slideshow_b8e38ba392d44ca085c10f7085e57a50-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_b8e38ba392d44ca085c10f7085e57a50-img").src = "data:image/png;base64," + images[i];
#                 document.getElementById("slideshow_b8e38ba392d44ca085c10f7085e57a50-counter").textContent = (i + 1) + " / " + total;
#             }
#
#             document.getElementById("slideshow_b8e38ba392d44ca085c10f7085e57a50-prev").onclick = function() {
#                 index = (index - 1 + images.length) % images.length;
#                 showImage(index);
#             };
#             document.getElementById("slideshow_b8e38ba392d44ca085c10f7085e57a50-next").onclick = function() {
#                 index = (index + 1) % images.length;
#                 showImage(index);
#             };
#         })();
#     </script>
# Graph [(1, 2), (2, 0), (3, 4), (4, 0), (5, 6), (6, 0)]
# Graceful labellings:
#     <div id="slideshow_ca624652b43044cc927cdb329842d5d8-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_ca624652b43044cc927cdb329842d5d8-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_ca624652b43044cc927cdb329842d5d8-counter">1 / 60</span>
#         </div>
#         <button id="slideshow_ca624652b43044cc927cdb329842d5d8-prev">Previous</button>
#         <button id="slideshow_ca624652b43044cc927cdb329842d5d8-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_ca624652b43044cc927cdb329842d5d8-img").src = "data:image/png;base64," + images[i];
#                 document.getElementById("slideshow_ca624652b43044cc927cdb329842d5d8-counter").textContent = (i + 1) + " / " + total;
#             }
#
#             document.getElementById("slideshow_ca624652b43044cc927cdb329842d5d8-prev").onclick = function() {
#                 index = (index - 1 + images.length) % images.length;
#                 showImage(index);
#             };
#             document.getElementById("slideshow_ca624652b43044cc927cdb329842d5d8-next").onclick = function() {
#                 index = (index + 1) % images.length;
#                 showImage(index);
#             };
#         })();
#     </script>
# Alpha-valuations:
# No alpha-valuations found.
# Graph [(0, 1), (1, 2), (2, 3), (3, 4)]
# Graceful labellings:
#     <div id="slideshow_4a4e8017a58b4b31ac9614780b399df1-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_4a4e8017a58b4b31ac9614780b399df1-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_4a4e8017a58b4b31ac9614780b399df1-counter">1 / 8</span>
#         </div>
#         <button id="slideshow_4a4e8017a58b4b31ac9614780b399df1-prev">Previous</button>
#         <button id="slideshow_4a4e8017a58b4b31ac9614780b399df1-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","...","...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_4a4e8017a58b4b31ac9614780b399df1-img").src = "data:image/png;base64," + images[i];
#                 document.getElementById("slideshow_4a4e8017a58b4b31ac9614780b399df1-counter").textContent = (i + 1) + " / " + total;
#             }
#
#             document.getElementById("slideshow_4a4e8017a58b4b31ac9614780b399df1-prev").onclick = function() {
#                 index = (index - 1 + images.length) % images.length;
#                 showImage(index);
#             };
#             document.getElementById("slideshow_4a4e8017a58b4b31ac9614780b399df1-next").onclick = function() {
#                 index = (index + 1) % images.length;
#                 showImage(index);
#             };
#         })();
#     </script>
# Alpha-valuations:
#     <div id="slideshow_b0c446d3a3444e489fd5783b1e8ac5e7-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_b0c446d3a3444e489fd5783b1e8ac5e7-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_b0c446d3a3444e489fd5783b1e8ac5e7-counter">1 / 4</span>
#         </div>
#         <button id="slideshow_b0c446d3a3444e489fd5783b1e8ac5e7-prev">Previous</button>
#         <button id="slideshow_b0c446d3a3444e489fd5783b1e8ac5e7-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_b0c446d3a3444e489fd5783b1e8ac5e7-img").src = "data:image/png;base64," + images[i];
#                 document.getElementById("slideshow_b0c446d3a3444e489fd5783b1e8ac5e7-counter").textContent = (i + 1) + " / " + total;
#             }
#
#             document.getElementById("slideshow_b0c446d3a3444e489fd5783b1e8ac5e7-prev").onclick = function() {
#                 index = (index - 1 + images.length) % images.length;
#                 showImage(index);
#             };
#             document.getElementById("slideshow_b0c446d3a3444e489fd5783b1e8ac5e7-next").onclick = function() {
#                 index = (index + 1) % images.length;
#                 showImage(index);
#             };
#         })();
#     </script>

# %%
edge_sets = [
    CycleGraph.edges(3) + [(0, 3), (3, 4), (4, 1)],
    CycleGraph.edges(3) + [(0, 3), (3, 1)],
    # CycleGraph.edges(4) + [(0, 4), (4, 5), (5, 6), (6, 1)],
    # CycleGraph.edges(4) + [(0, 4), (4, 5), (5, 1)],
    # CycleGraph.edges(4) + [(0, 4), (4, 5)],
]

for edges in edge_sets:
    graph = nx.Graph(edges)
    layout = nx.spring_layout(graph)
    print("Graceful labellings:")
    try:
        draw_graphs(find_graceful_labellings(graph), layout=layout)
    except StopIteration:
        print("No graceful labellings found.")
    # print("Alpha-valuations:")
    # try:
    #     draw_graphs(find_alpha_valuations(graph), layout=layout)
    # except StopIteration:
    #     print("No alpha-valuations found.")
    print("Eta-valuations:")
    try:
        draw_graphs(find_eta_valuations(graph), layout=layout)
    except StopIteration:
        print("No eta-valuations found.")
# Out:
# Graceful labellings:
#     <div id="slideshow_f189235cc7f94bb3b114cfc8b54dbc24-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_f189235cc7f94bb3b114cfc8b54dbc24-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_f189235cc7f94bb3b114cfc8b54dbc24-counter">1 / 52</span>
#         </div>
#         <button id="slideshow_f189235cc7f94bb3b114cfc8b54dbc24-prev">Previous</button>
#         <button id="slideshow_f189235cc7f94bb3b114cfc8b54dbc24-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_f189235cc7f94bb3b114cfc8b54dbc24-img").src = "data:image/png;base64," + images[i];
#                 document.getElementById("slideshow_f189235cc7f94bb3b114cfc8b54dbc24-counter").textContent = (i + 1) + " / " + total;
#             }
#
#             document.getElementById("slideshow_f189235cc7f94bb3b114cfc8b54dbc24-prev").onclick = function() {
#                 index = (index - 1 + images.length) % images.length;
#                 showImage(index);
#             };
#             document.getElementById("slideshow_f189235cc7f94bb3b114cfc8b54dbc24-next").onclick = function() {
#                 index = (index + 1) % images.length;
#                 showImage(index);
#             };
#         })();
#     </script>
# Eta-valuations:
#     <div id="slideshow_63689ede3bf04afb8111f3dc36d1f9e2-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_63689ede3bf04afb8111f3dc36d1f9e2-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_63689ede3bf04afb8111f3dc36d1f9e2-counter">1 / 8</span>
#         </div>
#         <button id="slideshow_63689ede3bf04afb8111f3dc36d1f9e2-prev">Previous</button>
#         <button id="slideshow_63689ede3bf04afb8111f3dc36d1f9e2-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","...","...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_63689ede3bf04afb8111f3dc36d1f9e2-img").src = "data:image/png;base64," + images[i];
#                 document.getElementById("slideshow_63689ede3bf04afb8111f3dc36d1f9e2-counter").textContent = (i + 1) + " / " + total;
#             }
#
#             document.getElementById("slideshow_63689ede3bf04afb8111f3dc36d1f9e2-prev").onclick = function() {
#                 index = (index - 1 + images.length) % images.length;
#                 showImage(index);
#             };
#             document.getElementById("slideshow_63689ede3bf04afb8111f3dc36d1f9e2-next").onclick = function() {
#                 index = (index + 1) % images.length;
#                 showImage(index);
#             };
#         })();
#     </script>
# Graceful labellings:
#     <div id="slideshow_ed5594a2f388492a8a970a86c60404a6-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_ed5594a2f388492a8a970a86c60404a6-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_ed5594a2f388492a8a970a86c60404a6-counter">1 / 32</span>
#         </div>
#         <button id="slideshow_ed5594a2f388492a8a970a86c60404a6-prev">Previous</button>
#         <button id="slideshow_ed5594a2f388492a8a970a86c60404a6-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_ed5594a2f388492a8a970a86c60404a6-img").src = "data:image/png;base64," + images[i];
#                 document.getElementById("slideshow_ed5594a2f388492a8a970a86c60404a6-counter").textContent = (i + 1) + " / " + total;
#             }
#
#             document.getElementById("slideshow_ed5594a2f388492a8a970a86c60404a6-prev").onclick = function() {
#                 index = (index - 1 + images.length) % images.length;
#                 showImage(index);
#             };
#             document.getElementById("slideshow_ed5594a2f388492a8a970a86c60404a6-next").onclick = function() {
#                 index = (index + 1) % images.length;
#                 showImage(index);
#             };
#         })();
#     </script>
# Eta-valuations:
#     <div id="slideshow_bf38fb5326ce4339a9f7d6442cc93e0b-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_bf38fb5326ce4339a9f7d6442cc93e0b-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_bf38fb5326ce4339a9f7d6442cc93e0b-counter">1 / 16</span>
#         </div>
#         <button id="slideshow_bf38fb5326ce4339a9f7d6442cc93e0b-prev">Previous</button>
#         <button id="slideshow_bf38fb5326ce4339a9f7d6442cc93e0b-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_bf38fb5326ce4339a9f7d6442cc93e0b-img").src = "data:image/png;base64," + images[i];
#                 document.getElementById("slideshow_bf38fb5326ce4339a9f7d6442cc93e0b-counter").textContent = (i + 1) + " / " + total;
#             }
#
#             document.getElementById("slideshow_bf38fb5326ce4339a9f7d6442cc93e0b-prev").onclick = function() {
#                 index = (index - 1 + images.length) % images.length;
#                 showImage(index);
#             };
#             document.getElementById("slideshow_bf38fb5326ce4339a9f7d6442cc93e0b-next").onclick = function() {
#                 index = (index + 1) % images.length;
#                 showImage(index);
#             };
#         })();
#     </script>

# %%
for n_vertices in [4, 6]:
    graph = nx.Graph(SunGraph.edges(n_vertices))
    layout = SunGraph.layout(n_vertices)
    # print("Graceful labellings:")
    # try:
    #     draw_graphs(find_graceful_labellings(graph), layout=layout)
    # except StopIteration:
    #     print("No graceful labellings found.")
    print("Alpha-valuations:")
    try:
        draw_graphs(find_alpha_valuations(graph), layout=layout)
    except StopIteration:
        print("No alpha-valuations found.")
    # print("Eta-valuations:")
    # try:
    #     draw_graphs(find_eta_valuations(graph), layout=layout)
    # except StopIteration:
    #     print("No eta-valuations found.")
# Out:
# Alpha-valuations:
#     <div id="slideshow_ec3a3753900c4c60844cda8e27c8431b-container" style="max-width:600px; text-align:center;">
#         <img id="slideshow_ec3a3753900c4c60844cda8e27c8431b-img" src="data:image/png;base64,..." style="width:100%; max-height:500px;"/>
#         <div style="margin: 8px 0;">
#             <span id="slideshow_ec3a3753900c4c60844cda8e27c8431b-counter">1 / 80</span>
#         </div>
#         <button id="slideshow_ec3a3753900c4c60844cda8e27c8431b-prev">Previous</button>
#         <button id="slideshow_ec3a3753900c4c60844cda8e27c8431b-next">Next</button>
#     </div>
#     <script>
#         (function() {
#             let images = ["...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","..."];
#             let index = 0;
#             const total = images.length;
#
#             function showImage(i) {
#                 document.getElementById("slideshow_ec3a3753900c4c60844cda8e27c8431b-img").src = "data:image/png;base64," + images[i];
#                 document.getElementById("slideshow_ec3a3753900c4c60844cda8e27c8431b-counter").textContent = (i + 1) + " / " + total;
#             }
#
#             document.getElementById("slideshow_ec3a3753900c4c60844cda8e27c8431b-prev").onclick = function() {
#                 index = (index - 1 + images.length) % images.length;
#                 showImage(index);
#             };
#             document.getElementById("slideshow_ec3a3753900c4c60844cda8e27c8431b-next").onclick = function() {
#                 index = (index + 1) % images.length;
#                 showImage(index);
#             };
#         })();
#     </script>
# Alpha-valuations:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 11
#       9 print("Alpha-valuations:")
#      10 try:
# ---> 11     draw_graphs(find_alpha_valuations(graph), layout=layout)
#      12 except StopIteration:
#      13     print("No alpha-valuations found.")
#
# File c:\Users\Gavin Angus\Documents\_main\code\git\graceful-labelling\graphs\tools\drawing.py:136, in draw_graphs(graphs, layout)
#     134     draw_graph(graphs, layout=layout)
#     135 else:
# --> 136     draw_slideshow(graphs, layout=layout)
#
# File c:\Users\Gavin Angus\Documents\_main\code\git\graceful-labelling\graphs\tools\drawing.py:66, in draw_slideshow(graphs, layout)
#      62 def draw_slideshow(
#      63     graphs: Iterable[nx.Graph], *, layout: Mapping[Vertex, Position] | None = None
#      64 ) -> None:
#      65     graph_drawings: list[str] = []
# ---> 66     for graph in graphs:
#      67         if layout is None:
#      68             layout = nx.spring_layout(graph)
#
# File c:\Users\Gavin Angus\Documents\_main\code\git\graceful-labelling\graphs\graceful_labellings\main.py:50, in find_alpha_valuations(graph)
#      48 def find_alpha_valuations(graph: nx.Graph) -> Generator[nx.Graph, None, None]:
#      49     # every alpha valuation is a graceful labelling (by definition)
# ---> 50     for graceful_graph in find_graceful_labellings(graph):
#      51         vertex_labels = nx.get_node_attributes(graceful_graph, "label")
#      52         labels_to_edges = {
#      53             label: edge
#      54             for edge, label in nx.get_edge_attributes(graceful_graph, "label").items()
#      55         }
#
# File c:\Users\Gavin Angus\Documents\_main\code\git\graceful-labelling\graphs\graceful_labellings\main.py:45, in find_graceful_labellings(graph)
#      36         if (
#      37             len(set(new_edge_labels.values())) == len(labelled_neighbors)
#      38             and set(new_edge_labels.values()) & set(edge_labels.values()) == set()
#      39         ):
#      40             yield from recurse(
#      41                 vertex_labels | {new_vertex: label},
#      42                 edge_labels | new_edge_labels,
#      43             )
# ---> 45 yield from recurse()
#
# File c:\Users\Gavin Angus\Documents\_main\code\git\graceful-labelling\graphs\graceful_labellings\main.py:40, in find_graceful_labellings.<locals>.recurse(vertex_labels, edge_labels)
#      32 new_edge_labels = {
#      33     (new_vertex, v): abs(label - vertex_labels[v])
#      34     for v in labelled_neighbors
#      35 }
#      36 if (
#      37     len(set(new_edge_labels.values())) == len(labelled_neighbors)
#      38     and set(new_edge_labels.values()) & set(edge_labels.values()) == set()
#      39 ):
# ---> 40     yield from recurse(
#      41         vertex_labels | {new_vertex: label},
#      42         edge_labels | new_edge_labels,
#      43     )
#
# File c:\Users\Gavin Angus\Documents\_main\code\git\graceful-labelling\graphs\graceful_labellings\main.py:40, in find_graceful_labellings.<locals>.recurse(vertex_labels, edge_labels)
#      32 new_edge_labels = {
#      33     (new_vertex, v): abs(label - vertex_labels[v])
#      34     for v in labelled_neighbors
#      35 }
#      36 if (
#      37     len(set(new_edge_labels.values())) == len(labelled_neighbors)
#      38     and set(new_edge_labels.values()) & set(edge_labels.values()) == set()
#      39 ):
# ---> 40     yield from recurse(
#      41         vertex_labels | {new_vertex: label},
#      42         edge_labels | new_edge_labels,
#      43     )
#
#     [... skipping similar frames: find_graceful_labellings.<locals>.recurse at line 40 (6 times)]
#
# File c:\Users\Gavin Angus\Documents\_main\code\git\graceful-labelling\graphs\graceful_labellings\main.py:40, in find_graceful_labellings.<locals>.recurse(vertex_labels, edge_labels)
#      32 new_edge_labels = {
#      33     (new_vertex, v): abs(label - vertex_labels[v])
#      34     for v in labelled_neighbors
#      35 }
#      36 if (
#      37     len(set(new_edge_labels.values())) == len(labelled_neighbors)
#      38     and set(new_edge_labels.values()) & set(edge_labels.values()) == set()
#      39 ):
# ---> 40     yield from recurse(
#      41         vertex_labels | {new_vertex: label},
#      42         edge_labels | new_edge_labels,
#      43     )
#
# File c:\Users\Gavin Angus\Documents\_main\code\git\graceful-labelling\graphs\graceful_labellings\main.py:38, in find_graceful_labellings.<locals>.recurse(vertex_labels, edge_labels)
#      31 for label in other_labels:
#      32     new_edge_labels = {
#      33         (new_vertex, v): abs(label - vertex_labels[v])
#      34         for v in labelled_neighbors
#      35     }
#      36     if (
#      37         len(set(new_edge_labels.values())) == len(labelled_neighbors)
# ---> 38         and set(new_edge_labels.values()) & set(edge_labels.values()) == set()
#      39     ):
#      40         yield from recurse(
#      41             vertex_labels | {new_vertex: label},
#      42             edge_labels | new_edge_labels,
#      43         )
#
# KeyboardInterrupt:

# %%
for n_vertices in [8]:
    graph = nx.Graph(SunGraph.edges(n_vertices))
    layout = SunGraph.layout(n_vertices)
    draw_graphs(next(find_alpha_valuations(graph)), layout=layout)
